# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive/

# %%
cd drive/My Drive/Image Captioning Gaurav
# Out:
# /content/drive/My Drive/Image Captioning Gaurav

# %%
ls Flicker8k_Dataset -1 | wc -l
# Out:
# 8091

# %%
ls evaluate/images
# Out:
# 2.jpg  3.jpg  4.jpg

# %%
# !python train.py --num_epochs 2
# Out:
# Using TensorFlow backend.
# 2020-05-13 18:29:14.810623: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# Loaded: 8092
# Vocabulary Size: 8763
# Dataset for training: 6000
# Descriptions: train=6000
# Photos: train=6000
# Dataset: 1000
# Descriptions: train=1000
# Photos: train=1000
# Vocabulary Size: 7579
# Description Length: 34
# Tokenizer saved
# Number of epochs  3
# Epoch: 1, Batch: 200, loss: 5.1483283042907715, avg loss: 0.11820203328355625
# Epoch: 1, Batch: 400, loss: 4.574087619781494, avg loss: 0.10979282342243775
# Epoch: 1, Batch: 600, loss: 4.312342166900635, avg loss: 0.10629381343083709
# Epoch: 1, Batch: 800, loss: 4.44423770904541, avg loss: 0.10330002261206549
# Epoch: 1, Batch: 1000, loss: 4.942547798156738, avg loss: 0.10090334903783035
# Epoch: 1, Batch: 1200, loss: 4.977469444274902, avg loss: 0.09909002947157368
# ...

# %%
# !python test.py --checkpoint "results/ckpt_epoch_1_batch_6000.pth"
# Out:
# Using TensorFlow backend.
# 2020-05-13 08:37:06.039456: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# Dataset: 1000
# Descriptions: test=1000
# Photos: test=1000
#
#
#
#
#
# BLEU-1: 0.546306
# BLEU-2: 0.290991
# BLEU-3: 0.194964
# BLEU-4: 0.086765

# %%
# !python evaluate.py --checkpoint "results/ckpt_epoch_2_batch_6000.pth"
# Out:
# Using TensorFlow backend.
# 2020-05-13 08:30:58.246824: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 3.jpg
# 4.jpg
# 2.jpg
# Complete
